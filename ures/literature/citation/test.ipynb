# %%
from pathlib import Path
from ures.literature.citation.checker import BibtexFactory
from ures.literature.citation.checker import CitationChecker

# %%
project_dir = Path('/Users/jiaboshi/Documents/003-Thesis/001-xMem-Middleware2025/dist')
bbl_file = project_dir / 'main.bbl'
tex_file = project_dir / 'main_expanded.tex'
bib_file = project_dir / 'references-latex.bib'

# %%
c_checker = CitationChecker(bib_file)
# Out:
# Parsing of `@article` block (line 5559) aborted on line 5563 due to syntactical error in bibtex:
#  Unexpected block start: `@`. Was still looking for field-value closing `}`
# Unknown block type <class 'bibtexparser.model.DuplicateBlockKeyBlock'>
# Unknown block type <class 'bibtexparser.model.DuplicateFieldKeyBlock'>
# Unknown block type <class 'bibtexparser.model.DuplicateFieldKeyBlock'>
# Unknown block type <class 'bibtexparser.model.DuplicateBlockKeyBlock'>
# Unknown block type <class 'bibtexparser.model.DuplicateFieldKeyBlock'>
# Unknown block type <class 'bibtexparser.model.DuplicateFieldKeyBlock'>
# Unknown block type <class 'bibtexparser.model.DuplicateFieldKeyBlock'>
# Unknown block type <class 'bibtexparser.model.DuplicateFieldKeyBlock'>
# Unknown block type <class 'bibtexparser.model.DuplicateFieldKeyBlock'>
# Unknown block type <class 'bibtexparser.model.DuplicateFieldKeyBlock'>
# Unknown block type <class 'bibtexparser.model.DuplicateFieldKeyBlock'>
# ...

# %%
citations = c_checker.import_citations([bbl_file, tex_file])

# %%
c_checker.get_invalid_citations()
# Out:
# ['biderman_pythia_2023',
#  'calderon_gmai_2020',
#  'grigorescu_survey_2020',
#  'gu_liquid_2022',
#  'hasan_study_2005',
#  'krizhevsky_imagenet_2017',
#  'liu_tbem_2022',
#  'pytorch_docker_2025',
#  '2020t5',
#  'rubinstein_simulation_2017',
#  'scheffe_analysis_1999',
#  'talha_deep_2023',
#  'tensorflow_tensorflow_2025',
#  '276938',
#  '288717',
#  '222611',
#  'yeung_horus_2022',
#  'MLSYS2020_d9cd83bc',
#  '211297']
